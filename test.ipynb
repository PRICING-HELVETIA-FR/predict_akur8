# %%
import pandas as pd
from src.predict_akur8.Akur8Model import Akur8Model
from src.predict_akur8.utils import report_unknown_values

# %%
model = Akur8Model.from_pickle('model.pkl')

# %%
df = pd.read_pickle('test_a_predire_next_payment.pkl')

# %%
out = model.predict(df, default_interpolation='nearest')

# %%
report_unknown_values(out)
# Out:
#               model                              variable           value  \
# 11  next_payment_v2  ('produit_recours_3', 'provision_1')      (nan, nan)
# 12  next_payment_v2  ('produit_recours_3', 'provision_1')      (0.0, nan)
# 15  next_payment_v2  ('produit_recours_3', 'provision_1')   (1678.0, nan)
# 14  next_payment_v2  ('produit_recours_3', 'provision_1')   (1706.0, nan)
# 13  next_payment_v2  ('produit_recours_3', 'provision_1')   (1776.0, nan)
# 1   next_payment_v2           ('provision_1', 'charge_2')      (nan, nan)
# 2   next_payment_v2           ('provision_1', 'charge_2')   (nan, 1776.0)
# 3   next_payment_v2           ('provision_1', 'charge_2')   (nan, 1950.0)
# 4   next_payment_v2           ('provision_1', 'charge_2')   (nan, 1706.0)
# 5   next_payment_v2           ('provision_1', 'charge_2')    (nan, 888.0)
# 6   next_payment_v2           ('provision_1', 'charge_2')      (nan, 0.0)
# 7   next_payment_v2           ('provision_1', 'charge_2')   (nan, 1678.0)
# 8   next_payment_v2           ('provision_1', 'charge_2')    (nan, 975.0)
# 9   next_payment_v2           ('provision_1', 'charge_2')    (nan, 925.0)
# 10  next_payment_v2           ('provision_1', 'charge_2')  (nan, 1763.29)
# 0   next_payment_v2                           provision_1             NaN
#
#      nb       pct
# 11  232  0.011089
# 12   25  0.001195
# 15    1  0.000048
# 14    6  0.000287
# 13   11  0.000526
# 1   229  0.010945
# 2    19  0.000908
# 3    18  0.000860
# 4     3  0.000143
# 5     1  0.000048
# 6     1  0.000048
# 7     1  0.000048
# 8     1  0.000048
# 9     1  0.000048
# 10    1  0.000048
# 0   275  0.013144
